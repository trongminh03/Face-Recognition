# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
eyes = np.array([[214, 107, 69, 69], [86, 123, 65, 65]])

# %%
glass = cv2.imread('images/glasses.png', cv2.IMREAD_UNCHANGED)
print(glass.shape)
transparent = glass[:,:,3] != 0
print(transparent.shape)
# Out:
# (221, 483, 4)
# (221, 483)

# %%
img = cv2.imread('test.jpg')
print(img.shape)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
if len(eyes) == 2:
    for (ex, ey, ew, eh) in eyes:
        cv2.rectangle(img, (ex, ey), (ex + ew, ey + eh), (0,255,0), 2)
    if eyes[0][0] > eyes[1][0]:
        tmp = eyes[0][0]
        eyes[0][0] = eyes[1][0]
        eyes[1][0] = tmp
    s = (eyes[0][0], eyes[0][1])
    e = (eyes[1][0] + eyes[1][2], eyes[1][1])
# print(img)
plt.imshow(img)
# Out:
# (667, 890, 3)

# %%
from imutils import face_utils, rotate_bound

def calculate_inclination(point1, point2):
    x1, x2, y1, y2 = point1[0], point2[0], point1[1], point2[1]
    incl = 180 / math.pi * math.atan((float(y2 - y1)) / (x2 - x1))
    return incl

beard = cv2.imread('images/santa_filter.png')
beard = rotate_bound(beard, -45)
plt.imshow(beard)
